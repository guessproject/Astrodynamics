# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import datetime
import porkchop as pc

# departure range
dep_planet = 'Earth'; dep_date = '25-10-2030'; #(format - dd-mm-yyyy)
dep_time_span = 240

#arrival range
arr_planet = 'Mars';  arr_date = '01-07-2031'; #(format - dd-mm-yyyy)
arr_time_span = 400
    
# variable to plot ('delv_plot' or 'c3_plot')
plot_values = 'delv_plot'

pc.make_porkchop_plot(dep_planet, dep_date, dep_time_span, arr_planet, arr_date, arr_time_span, plot_values)
